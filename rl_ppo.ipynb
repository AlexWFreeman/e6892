# %%
# !pip install -q gemma datasets grain

# %%
from kauldron import konfig
import treescope
from gemma import gm
from kauldron import kd
import optax
import os

import dataclasses
from kauldron.typing import Bool, Dim, Float, Int, Schedule, typechecked
import jax.numpy as jnp
from kauldron import kontext
import jax

from datasets import load_dataset, Dataset
import pandas as pd
from grain import python as grain
from typing import Mapping, Optional, Any, Generic, Optional, Protocol, SupportsIndex
import functools

from gemma.gm.ckpts._checkpoint import *
from gemma.gm.ckpts._lora import *
from kauldron.train.train_step import *
from kauldron.train import trainer_lib

# %%
workdir = '/content/drive/My Drive/my_ckpt/rl'
sft_workdir = '/content/drive/My Drive/my_ckpt/sft'
sft_ckpt = f'{sft_workdir}/checkpoints/ckpt_10000'

# %%
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="false"
os.environ["XLA_PYTHON_CLIENT_MEM_FRACTION"]=".80"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"]="platform"

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from huggingface_hub import login

# Log in with your token (Replace with your actual Hugging Face token)
token = "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"  # Replace with your token
login(token=token, add_to_git_credential=True)

# %%
fiqa_raw = load_dataset("TheFinAI/fiqa-sentiment-classification")
fiqa_df = {k: pd.DataFrame(v) for k, v in fiqa_raw.items()}

sft_df = {}
for key in ['train', 'val', 'test']:
    sft_df[key] = pd.read_csv(f'/content/drive/My Drive/my_dataset/sft/{key}.csv')
    sft_df[key]['score'] = sft_df[key]['label'].map({
        "positive":  1.0,
        "negative": -1.0,
        "neutral":   0.0
    })
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
fiqa_df['test']
# Out:
#        _id                                           sentence  \
# 0      645  Britain's FTSE steadies, supported by Dixons C...
# 1      651  Glaxo's ViiV Healthcare Signs China Manufactur...
# 2      653   AstraZeneca sells Caprelsa rights to Sanofi unit
# 3      659  UPDATE 5-Barclays Chairman McFarlane axes CEO ...
# 4      665  Miners Meltdown as BHP to Rio Tinto Sink in Co...
# ..     ...                                                ...
# 229  19130  Facebook $FB received a Buy rating from Wells ...
# 230  19149  $TSLA Wish had my puts back but see if we can ...
# 231  19161  Citrix Systems Inc $CTXS Position Increased by...
# 232  19163  Notable gainers among liquid option names this...
# 233  19167  Is #Facebook's user engagement falling? https:...
#
#               target                                        aspect  score  \
# 0    Dixons Carphone                            Stock/Price Action  0.329
# ...

# %%
@dataclasses.dataclass(frozen=True)
class MyLoadCheckpoint(kd.ckpts.AbstractPartialLoader):
    path: epath.PathLike
    quantize: bool = False

    def transform(self, state):
        params = gm.ckpts.load_params(self.path)
        return dataclasses.replace(state, params=params)

@dataclasses.dataclass(frozen=True)
class MySkipLoRA(kd.ckpts.AbstractPartialLoader):
    wrapped: kd.ckpts.AbstractPartialLoader

    def transform(self, state):
        state = self.wrapped.transform(state)
        return state

# %%
class DataFrameDataSource(grain.RandomAccessDataSource[dict]):
    def __init__(self, dataframe: pd.DataFrame):
        """
        Args:
            dataframe: A pandas DataFrame with columns 'dst' and 'src'.
        """
        self.dataframe = dataframe

    def __len__(self) -> int:
        return len(self.dataframe)

    def __getitem__(self, record_key: SupportsIndex) -> dict:
        row = self.dataframe.iloc[record_key]
        result = {
            "sentence": row["sentence"]
        }
        if "label" in row:
            result["label"] = row["label"].capitalize()
        if "score" in row:
            result["score"] = row["score"]
        return result

    def __repr__(self) -> str:
        return f"{self.__class__.__name__}(num_records={len(self)})"

# %%
# Inherit from the original Tfds and override data_source.
@dataclasses.dataclass(frozen=True)
class MyTfds(kd.data.py.Tfds):
    df: pd.DataFrame

    @functools.cached_property
    def data_source(self) -> DataFrameDataSource:
        return DataFrameDataSource(dataframe=self.df[self.split])

# %%
tokenizer = gm.text.Gemma3Tokenizer()
prompt_template = """<start_of_turn>user
Please classify the sentiment of the following financial text, please answer only with Positive, Negative, or Neutral.
Text: {text}<end_of_turn>
<start_of_turn>model"""

# %%
def make_dataset(df, name, split, label=False, eval=False):
    _INPUT_FIELD = "sentence"
    _LABEL_FIELD = "label" if label else "score"

    return MyTfds(
        name=name,
        split=split,
        shuffle=False if eval else True,
        num_epochs=1 if eval else None,
        batch_size=8,
        df=df,
        transforms=[
            gm.data.FormatText(
                key=_INPUT_FIELD,
                template=prompt_template,
            ),
            gm.data.Tokenize(
                key=_INPUT_FIELD,
                tokenizer=tokenizer,
                add_bos=True,
            ),
            gm.data.Pad(
                key=_INPUT_FIELD,
                max_length=256,
            ),
            *([
                gm.data.Tokenize(
                    key=_LABEL_FIELD,
                    tokenizer=tokenizer
                )]
                if label else []
            ),
            kd.data.Rearrange(
                key=_LABEL_FIELD,
                pattern="... -> ...",
            ),
        ]
    )

sft_ds = {
    split: make_dataset(sft_df, 'sft', split, True, eval) \
    for split, eval in zip(['train', 'val', 'test'], [False, True, True])
}

ex_sft = sft_ds['train'][0]
treescope.show(ex_sft)

print(tokenizer.decode(ex_sft['sentence'][0]))
# Out:
# {
#   'label': # np.ndarray int64(8, 1) [≥20_809, ≤63_702] nonzero:8
#     array([[20809],
#            [48084],
#            [48084],
#            [20809],
#            [63702],
#            [20809],
#            [63702],
#            [20809]])
#   ,
#   'score': np.array([ 0.,  1.,  1.,  0., -1.,  0., -1.,  0.]),
#   'sentence': <np.ndarray int64(8, 256) [≥0, ≤254_675] zero:1_585 nonzero:463>,
# }
# <start_of_turn>user
# Please classify the sentiment of the following financial text, please answer only with Positive, Negative, or Neutral.
# Text: Following the increase the company+EUR TM s capital totals 5.5 mln Romanian lei $ 1.98 mln-1 .56 mln euro .<end_of_turn>
# <start_of_turn>model

# %%
fiqa_ds = {
    split: make_dataset(fiqa_df, 'rl', split, False, eval) \
    for split, eval in zip(['train', 'valid', 'test'], [False, True, True])
}

ex = fiqa_ds['train'][0]
treescope.show(ex)

print(tokenizer.decode(ex['sentence'][0]))
# Out:
# {
#   'score': np.array([ 0.655,  0.437, -0.057,  0.432,  0.663,  0.142,  0.527,  0.221]),
#   'sentence': # np.ndarray int64(8, 256) [≥0, ≤236_935] zero:1_607 nonzero:441
#     array([[   2,  105, 2364, ...,    0,    0,    0],
#            [   2,  105, 2364, ...,    0,    0,    0],
#            [   2,  105, 2364, ...,    0,    0,    0],
#            ...,
#            [   2,  105, 2364, ...,    0,    0,    0],
#            [   2,  105, 2364, ...,    0,    0,    0],
#            [   2,  105, 2364, ...,    0,    0,    0]])
#   ,
# }
# <start_of_turn>user
# Please classify the sentiment of the following financial text, please answer only with Positive, Negative, or Neutral.
# Text: like $T for a breakout long as well. getting through the 100 and 200 MA could see it run.<end_of_turn>
# <start_of_turn>model

# %%
@dataclasses.dataclass(frozen=True, kw_only=True)
class PPOLoss(kd.losses.Loss):
    scores:        kontext.Key = kontext.REQUIRED
    policy_logits: kontext.Key = kontext.REQUIRED
    anchor_logits: kontext.Key = kontext.REQUIRED
    clip_eps:      float       = 0.2

    @typechecked
    def get_values(
        self,
        *,
        scores: Float['*B'],
        policy_logits: Float['*B V'],
        anchor_logits: Float['*B V'],
    ) -> Float['*B 1']:
        # print(scores.shape, policy_logits.shape, anchor_logits.shape)
        label_ids      = jnp.array([63702, 20809, 48084], dtype=jnp.int32)
        pol_lbl_logits = policy_logits[:, label_ids]    # [B,3]
        anch_lbl_logits= anchor_logits[:, label_ids]    # [B,3]

        logp     = jax.nn.log_softmax(pol_lbl_logits,  axis=-1)  # [B,3]
        logp_old = jax.nn.log_softmax(anch_lbl_logits, axis=-1)  # [B,3]
        ratio    = jnp.exp(logp - logp_old)                      # [B,3]

        value_map = jnp.array([-1.0, 0.0, 1.0])                         # [3]
        r_mat     = 1.0 - jnp.abs(scores[:, None] - value_map[None, :]) # [B,3]

        pi_old    = jnp.exp(logp_old)                                # [B,3]
        baseline  = jnp.sum(pi_old * r_mat, axis=-1, keepdims=True)  # [B,1]
        adv       = r_mat - baseline                                 # [B,3]

        adv       = (adv - jnp.mean(adv)) / (jnp.std(adv) + 1e-8)    # [B,3]
        clipped_ratio = jnp.clip(ratio,
                                 1.0 - self.clip_eps,
                                 1.0 + self.clip_eps)                # [B,3]

        surr1 = ratio         * adv        # [B,3]
        surr2 = clipped_ratio * adv        # [B,3]
        surr  = jnp.minimum(surr1, surr2)  # [B,3]

        loss = -jnp.sum(pi_old * surr, axis=-1, keepdims=True)  # [B,1]
        return loss

# %%
@dataclasses.dataclass(kw_only=True, eq=True, frozen=True)
class MyTrainStep(TrainStep):
    """Identical to TrainStep, but clears JAX compile caches after each step."""

    @functools.partial(
        jax.jit,
        static_argnames=(
            "self",
            "return_losses",
            "return_metrics",
            "return_summaries",
            "checkify_error_categories",
        ),
        donate_argnames=("state",),
    )
    @jax.named_call
    def step(
        self,
        state: TrainState,
        batch: PyTree[Any],
        *,
        return_losses: bool = False,
        return_metrics: bool = False,
        return_summaries: bool = False,
        checkify_error_categories: frozenset[trainer_lib.CheckifyErrorCategory] = frozenset(),
    ) -> tuple[TrainState, auxiliaries.AuxiliariesState]:
        # 1) Call the original jitted step
        new_state, aux_state = super().step(
            state,
            batch,
            return_losses=return_losses,
            return_metrics=return_metrics,
            return_summaries=return_summaries,
            checkify_error_categories=checkify_error_categories,
        )
        # 2) Clear JAX compilation & staging caches on the host
        jax.clear_caches()
        return new_state, aux_state

# %%
trainer = kd.train.Trainer(
    seed=42,
    workdir=workdir,
    train_ds=fiqa_ds['train'],
    # Model definition
    model=gm.nn.AnchoredPolicy(
        policy=gm.nn.LoRA(
            rank=4,
            model=gm.nn.Gemma3_4B(tokens="batch.sentence",
                                  return_last_only=True, text_only=True),
        ),
    ),
    init_transform=gm.ckpts.AnchoredPolicyLoader(
        policy=MySkipLoRA(
            wrapped=MyLoadCheckpoint(
                path=sft_ckpt,
            ),
        )
    ),
    # Training (should be 10_000)
    num_train_steps=1000,
    train_losses={
        "dpo": PPOLoss(
            scores="batch.score",
            policy_logits="preds.policy.logits",
            anchor_logits="preds.anchor.logits",
        ),
    },
    optimizer=kd.optim.partial_updates(
        optax.adafactor(learning_rate=1e-4),
        mask=kd.optim.select("lora"),
    ),
    checkpointer=kd.ckpts.Checkpointer(
        save_interval_steps=500,
    ),
    # Evaluation
    evals={
        "eval": kd.evals.Evaluator(
            num_batches=None,
            run=kd.evals.EveryNSteps(100),
            ds=fiqa_ds['valid'],
        ),
        "test": kd.evals.Evaluator(
            num_batches=None,
            run=kd.evals.EveryNSteps(100),
            ds=sft_ds['val'],
            metrics={
                "accuracy": kd.metrics.Accuracy(
                    logits="preds.policy.logits",
                    labels="batch.label",
                ),
            },
        ),
    },
    # trainstep=MyTrainStep(),
)

# %%
state, aux = trainer.train()
# Out:
# /usr/local/lib/python3.11/dist-packages/kauldron/data/utils.py:80: UserWarning: Explicitly requested dtype float64 requested in empty is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return jnp.empty(spec.shape, dtype)
# /usr/local/lib/python3.11/dist-packages/jax/_src/numpy/array_creation.py:151: UserWarning: Explicitly requested dtype float64 requested in zeros is not available, and will be truncated to dtype float32. To enable more dtypes, set the jax_enable_x64 configuration option or the JAX_ENABLE_X64 shell environment variable. See https://github.com/jax-ml/jax#current-gotchas for more.
#   return zeros(shape, dtype, device=device)
# Disabling pygrain multi-processing (unsupported in colab).
# Starting training loop at step 0
# ...
# eval:   0%|          | 0/14 [00:00<?, ?it/s]
# ...

# %%
# !mkdir -p /tmp/workdir
# !cp -r "{workdir}/test" /tmp/workdir
# %load_ext tensorboard
# %tensorboard --logdir '/tmp/workdir/test'
